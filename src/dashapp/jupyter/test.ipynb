# %%
import numpy as np
import pandas as pd

# %%
pd = pd.read_csv(r'../data/infection_summary_demo1.csv')

# %%
for i in range(len(pd)):
    if pd.loc[i, 'Assis'] == 'D':
        pd = pd.drop(i)
pd
# Out:
#        time_stamp  susceptible  exposed  asymptomatic  symptomatic  severe  \
# 0               3          740        0            10            0       0
# 2               7          740        0            10            0       0
# 4              11          740        0            10            0       0
# 6              15          740        0            10            0       0
# 8              19          740        0            10            0       0
# 10             23          740        0            10            0       0
# 12             27          740        0            10            0       0
# 14             31          740        0            10            0       0
# 15             33          740        0            10            0       0
# 17             37          740        0            10            0       0
# 19             41          740        0            10            0       0
# ...

# %%
pd.to_csv('../data/infection_summary_demo1.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-37d89eea9894> in <module>()
# ----> 1 pd.to_csv('../data/infection_summary_demo1.csv')
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
business_map = pd.read_csv(r'../../../config/map/business.csv')

# %%
business_map
# Out:
#    building_type  min_workhour  max_workhour  min_start_hour  max_start_hour  \
# 0     restaurant            10            12              10              11
# 1     barbershop             8            12               9              11
# 2         retail            10            12               8              10
# 3       hospital            24            24               0               0
# 4  train_station            24            24               0               0
#
#         day  min_activity_per_week  max_activity_per_week  \
# 0  everyday                      5                      7
# 1  everyday                      5                      7
# 2  everyday                      6                      7
# 3  everyday                      7                      7
# 4  everyday                      7                      7
#
#    open_24_hours_chance
# 0                   0.1
# 1                   0.0
# 2                   0.1
# 3                   1.0
# 4                   1.0

# %%
business_map['min_workhour'][0]
# Out:
# 10

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Jason\\Desktop\\Epidemicon Research\\experiment\\Koudou\\src\\dashapp\\jupyter'

# %%
import json
import pandas as pd
import os

evacuation_map = pd.read_json(os.getcwd()+'../../../config/map/evacuation_center.json', encoding="utf-8", orient='records')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-1b0fc095e880> in <module>()
#       3 import os
#       4
# ----> 5 evacuation_map = pd.read_json(os.getcwd()+'../../../config/map/evacuation_center.json', encoding="utf-8", orient='records')
#
# D:\conda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# D:\conda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
from pandas.io.json import json_normalize

data=open('C:\\Users\\Jason\\Desktop\\Epidemicon Research\\experiment\\Koudou\\config\\map\\evacuation_center.json',encoding="utf-8").read()
data_list=json.loads(data)
df=json_normalize(data_list)
# Out:
# D:\conda\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """

# %%
df
# Out:
#                                   evacuation_centers
# 0  [{'selection': 'by_id', 'rules': {'place_id': ...

# %%
df = pd.read_json('C:\\Users\\Jason\\Desktop\\Epidemicon Research\\experiment\\Koudou\\config\\map\\evacuation_center.json',
                encoding='utf-8',
                orient="records")
df
# Out:
#                                   evacuation_centers
# 0  {'selection': 'by_id', 'rules': {'place_id': '...
# 1  {'selection': 'by_id', 'rules': {'place_id': '...
# 2  {'selection': 'by_id', 'rules': {'place_id': '...
# 3  {'selection': 'by_id', 'rules': {'place_id': '...
# 4  {'selection': 'by_id', 'rules': {'place_id': '...
# 5  {'selection': 'by_id', 'rules': {'place_id': '...
# 6  {'selection': 'by_id', 'rules': {'place_id': '...
# 7  {'selection': 'by_id', 'rules': {'place_id': '...

# %%
df.iloc[0][0]
# Out:
# {'selection': 'by_id',
#  'rules': {'place_id': '487758238'},
#  'attributes': {'name': 'Kasuga Gakuen Obligatory Education School',
#   'capacity': 1500,
#   'contains_food': True,
#   'contains_medicine': False}}

# %%
len(df.iloc[0][0]['attributes'])
# Out:
# 4

# %%
df.iloc[1][0]['attributes'].keys()
# Out:
# dict_keys(['name', 'capacity', 'contains_food', 'contains_medicine'])

# %%
len(df)
evacuation_map = df

# %%
    value_list = []
    for i in range(len(evacuation_map)):
        single_list = []
        single_list.append(i+1)
        single_list.append(evacuation_map.iloc[i][0]["selection"])
        single_list.append(evacuation_map.iloc[i][0]["rules"]["place_id"])
        single_list.append(evacuation_map.iloc[i][0]["attributes"]["name"])
        single_list.append(evacuation_map.iloc[i][0]["attributes"]["capacity"])
        single_list.append(evacuation_map.iloc[i][0]["attributes"]["contains_food"])
        single_list.append(evacuation_map.iloc[i][0]["attributes"]["contains_medicine"])
        value_list.append(single_list)

# %%
value_list
# Out:
# [[1,
#   'by_id',
#   '487758238',
#   'Kasuga Gakuen Obligatory Education School',
#   1500,
#   True,
#   False],
#  [2, 'by_id', '144198893', 'Azuma Elementary School', 1500, True, False],
#  [3, 'by_id', '260552751', 'Kasuga Exchange Center', 1500, True, False],
#  [4, 'by_id', '143970885', 'Tsukuba Capio', 1500, True, False],
#  [5, 'by_id', '143801539', 'Tsukuba Innovation Plaza', 1500, True, False],
#  [6, 'by_id', '216503324', 'Joyo Bank Azuma', 1500, True, False],
#  [7, 'by_id', '281239292', 'Tsukuba Bank Headquarters', 1500, True, False],
#  [8, 'by_id', '426073131', 'Azuma Exchange Center', 1500, True, False]]

# %%
f.open('log.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-64f64b2db3ea> in <module>()
# ----> 1 f.open('log.txt')
#
# NameError: name 'f' is not defined

# %%
f = open('C:\\Users\\Jason\Desktop\\Epidemicon Research\\experiment\\Koudou\\src\\dashapp\\data\\log_result\\log.txt')

# %%
f
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Jason\\Desktop\\Epidemicon Research\\experiment\\Koudou\\src\\dashapp\\data\\log_result\\log.txt' mode='r' encoding='cp936'>

# %%
lines = f.readlines()

# %%
len(lines)
# Out:
# 339

# %%
lines[0]
# Out:
# '[debug] : List of Parameters\n'
